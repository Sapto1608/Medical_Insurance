# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn import metrics

# %% [markdown]
# # Reading csv file

# %%
data=pd.read_csv(r"C:\Users\User\OneDrive\Desktop\machine_learning\Medicalpremium.csv")

# %%
data.shape
# Out:
# (986, 11)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 986 entries, 0 to 985
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      986 non-null    int64
#  1   Diabetes                 986 non-null    int64
#  2   BloodPressureProblems    986 non-null    int64
#  3   AnyTransplants           986 non-null    int64
#  4   AnyChronicDiseases       986 non-null    int64
#  5   Height                   986 non-null    int64
#  6   Weight                   986 non-null    int64
#  7   KnownAllergies           986 non-null    int64
#  8   HistoryOfCancerInFamily  986 non-null    int64
#  9   NumberOfMajorSurgeries   986 non-null    int64
#  10  PremiumPrice             986 non-null    int64
# dtypes: int64(11)
# memory usage: 84.9 KB

# %%
data
# Out:
#      Age  Diabetes  BloodPressureProblems  AnyTransplants  AnyChronicDiseases  \
# 0     45         0                      0               0                   0
# 1     60         1                      0               0                   0
# 2     36         1                      1               0                   0
# 3     52         1                      1               0                   1
# 4     38         0                      0               0                   1
# ..   ...       ...                    ...             ...                 ...
# 981   18         0                      0               0                   0
# 982   64         1                      1               0                   0
# 983   56         0                      1               0                   0
# 984   47         1                      1               0                   0
# 985   21         0                      0               0                   0
#
# ...

# %% [markdown]
# # Checking for missing values

# %%
data.isnull().sum()
# Out:
# Age                        0
# Diabetes                   0
# BloodPressureProblems      0
# AnyTransplants             0
# AnyChronicDiseases         0
# Height                     0
# Weight                     0
# KnownAllergies             0
# HistoryOfCancerInFamily    0
# NumberOfMajorSurgeries     0
# PremiumPrice               0
# dtype: int64

# %% [markdown]
# #
# Describing data

# %%
data.describe()
# Out:
#               Age    Diabetes  BloodPressureProblems  AnyTransplants  \
# count  986.000000  986.000000             986.000000      986.000000
# mean    41.745436    0.419878               0.468560        0.055781
# std     13.963371    0.493789               0.499264        0.229615
# min     18.000000    0.000000               0.000000        0.000000
# 25%     30.000000    0.000000               0.000000        0.000000
# 50%     42.000000    0.000000               0.000000        0.000000
# 75%     53.000000    1.000000               1.000000        0.000000
# max     66.000000    1.000000               1.000000        1.000000
#
#        AnyChronicDiseases      Height      Weight  KnownAllergies  \
# count          986.000000  986.000000  986.000000      986.000000
# mean             0.180527  168.182556   76.950304        0.215010
# std              0.384821   10.098155   14.265096        0.411038
# min              0.000000  145.000000   51.000000        0.000000
# ...

# %%
# Checking for duplicate values
data.duplicated().sum()
# Out:
# 0

# %%
# Checking correlation wrt to Diabetes
data.corr()['Diabetes']
# Out:
# Age                        0.210908
# Diabetes                   1.000000
# BloodPressureProblems      0.127727
# AnyTransplants            -0.036652
# AnyChronicDiseases        -0.089428
# Height                    -0.003783
# Weight                    -0.024563
# KnownAllergies            -0.080102
# HistoryOfCancerInFamily   -0.055527
# NumberOfMajorSurgeries     0.122722
# PremiumPrice               0.076209
# Name: Diabetes, dtype: float64

# %%
# Drawing pie chart for known allergies
data['KnownAllergies'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # Drawing Histogram for Ages

# %%
sns.histplot(data['Age'],bins=10,edgecolor='red',kde=True,stat='density')
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
# Checking for skewness
print(data['Age'].skew())
print('Very slightly positively skewed')
# Out:
# 0.02989532159556419
# Very slightly positively skewed

# %% [markdown]
# # Drawing Histogram for Heights

# %%
sns.histplot(data['Height'],bins=10,edgecolor='red',kde=True,stat='density')
# Out:
# <Axes: xlabel='Height', ylabel='Density'>

# %%
# Checking for skewness
print(data['Height'].skew())
print('Slightly negatively skewed')
# Out:
# -0.1797880797544121
# Slightly negatively skewed

# %% [markdown]
# # Drawing Histogram for Weights

# %%
sns.histplot(data['Weight'],bins=10,edgecolor='red',kde=True,stat='density')
# Out:
# <Axes: xlabel='Weight', ylabel='Density'>

# %%
# Checking for skewness
print(data['Weight'].skew())
print('Positively skewed')
# Out:
# 0.666726314567332
# Positively skewed

# %% [markdown]
# # Boxplot for the Premium Price

# %%
sns.boxplot(data['PremiumPrice'])
# Out:
# <Axes: ylabel='PremiumPrice'>

# %% [markdown]
# # Heatmap

# %%
plt.figure(figsize=(14,8))
sns.heatmap(data.corr(), annot = True, cmap='coolwarm',linewidths=.1)
plt.title("Heatmap for correlation between columns")
plt.show()

# %% [markdown]
# # Pairplots

# %%
sns.pairplot(data,hue = 'PremiumPrice',diag_kind = "kde",kind = "scatter",palette = "husl")
plt.show()
